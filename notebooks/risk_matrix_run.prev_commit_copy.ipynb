# %%
import os, io, time, json, hashlib, pathlib, sys
import requests
import pandas as pd
import numpy as np
import importlib
from dotenv import load_dotenv
import re
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from urllib.parse import urlparse
from datetime import datetime, timedelta
import geoquant.configs.config as config
import geoquant.data_io as f1
import geoquant.series_utils as f2
import geoquant.risk_matrix as risk_matrix
import geoquant.books as books
import logging

# print(holdings.IBKR_live)

importlib.reload(books)
importlib.reload(f2)
importlib.reload(config)

logging.getLogger().setLevel(logging.DEBUG)
print('ok')
# Out:
# ok

# %%
PORTFOLIO = 'IBKR_live' 
    
holdings=getattr(books, PORTFOLIO)  # verify it exists

print('holdings:', holdings)

data_params = config.data_params
print('data_params:', data_params)
DEBUG = False
print('------\nBOOK:', PORTFOLIO, '\n-------')
max_age = data_params.get('max_age', 0)
print('max_age (hrs):', max_age, '\n-------')

rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)

risk = risk_matrix.portfolio_risk(rets_df, w)

# print( rets_df.tail(3) )
print("------------\nPortfolio σ (an_adjnualized, CHF): {:.2%}".format(risk["port_vol"]))
print(" CORE EQUITY BAND = 15 - 30%, DIVERSIFIERS = 5 - 12%, TACTICALS <= 10%,")
print('equity core max 30%, diversifiers max 12%, tacticals max 10%, total max 15%')
print('RISK ["SUMMARY"]:')
print(risk["summary"].round({"Weight":3,"Vol_1Y_CHF":3,"MRC":3,"PRC_%":1, }))
print(f'CORRELATION:')
print(f'{risk["corr"].round(2)}')
print(f'COVARIANCE:')
print(f'{risk["cov_annual"]}')

corr_matrix = risk["corr"]

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title(f"Correlation Matrix: {PORTFOLIO}")
plt.show()
# Out:
# DEBUG:geoquant.risk_matrix:++++++ build_returns_weights()
# DEBUG:geoquant.data_io:+++fetch_csv : GBPCHF.FOREX, config/data_params:
# DEBUG:geoquant.data_io:GBPCHF - using cached data (no refresh)
# INFO:geoquant.data_io:changes: []
# INFO:geoquant.data_io:  GBPCHF - no flat-bar spikes detected in cached data
# DEBUG:geoquant.data_io:+++fetch_csv : JPYCHF.FOREX, config/data_params:
# DEBUG:geoquant.data_io:JPYCHF - using cached data (no refresh)
# INFO:geoquant.data_io:changes: []
# INFO:geoquant.data_io:  JPYCHF - no flat-bar spikes detected in cached data
# DEBUG:geoquant.data_io:+++fetch_csv : USDCHF.FOREX, config/data_params:
# DEBUG:geoquant.data_io:USDCHF - using cached data (no refresh)
# INFO:geoquant.data_io:changes: []
# INFO:geoquant.data_io:  USDCHF - no flat-bar spikes detected in cached data
# DEBUG:geoquant.risk_matrix:===========building price series df===============
# DEBUG:geoquant.risk_matrix:--------holdings-loop-XMWX--------
# DEBUG:geoquant.risk_matrix:>>>>>>>>>>>>>> Processing XMWX >>>>>>>>
# DEBUG:geoquant.data_io:+++fetch_csv : XMWX.LSE, config/data_params:
# DEBUG:geoquant.data_io:XMWX.UK - using cached data (no refresh)
# INFO:geoquant.data_io:XMWX.UK gap days: 2437
# INFO:geoquant.data_io:XMWX.UK required start: 2018-01-01 00:00:00
#  XMWX.UK data start: 2024-09-03
# INFO:geoquant.data_io:changes: []
# INFO:geoquant.data_io:  XMWX.UK - no flat-bar spikes detected in cached data
# DEBUG:geoquant.risk_matrix:               Open    High     Low   Close  Volume
# Date
# 2026-05-08  32.5032  32.705  32.425  32.515   42610
# INFO:geoquant.series_utils:Spike check: XMWX (top 10, threshold 0.07)
# INFO:geoquant.series_utils:Spike check FAILED for XMWX: 8 spikes exceed threshold 0.07
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 92, in build_returns_weights
#     logger.debug('px local earliest date', sx.index[0].date())
# Message: 'px local earliest date'
# Arguments: (datetime.date(2024, 9, 3),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 93, in build_returns_weights
#     logger.debug('px local latest', sx.iloc[-1])
# Message: 'px local latest'
# Arguments: (np.float64(32.515),)
# DEBUG:geoquant.risk_matrix:<bound method NDFrame.tail of Date
# 2024-09-03    25.1225
# 2024-09-04    24.8425
# 2024-09-05    24.7600
# 2024-09-06    24.4375
# 2024-09-09    24.7375
#                ...
# 2026-05-01    32.2600
# 2026-05-05    32.1750
# 2026-05-06    32.8950
# 2026-05-07    32.6650
# 2026-05-08    32.5150
# Name: Close, Length: 425, dtype: float64>
# DEBUG:geoquant.risk_matrix:Max data gap (days) for XMWX: 5.0
# holdings: [{'name': 'XMWX', 'ticker': 'XMWX.LSE', 'ccy': 'GBP', 'GBP_exposure': 0.1, 'gbx': False, 'position': 497, 'target_weight': 0.3}, {'name': 'EMIM', 'ticker': 'EMIM.LSE', 'ccy': 'GBP', 'USD_exposure': 0, 'gbx': True, 'position': 321, 'target_weight': 0.25}, {'name': 'GWX', 'ticker': 'GWX.US', 'ccy': 'USD', 'USD_exposure': 0, 'gbx': False, 'position': 203, 'target_weight': 0.15}, {'name': 'VUAG', 'ticker': 'VUAG.LSE', 'ccy': 'GBP', 'USD_exposure': 1.0, 'gbx': False, 'position': 39, 'target_weight': 0.1}, {'name': 'SGLN', 'ticker': 'SGLN.LSE', 'ccy': 'GBP', 'USD_exposure': 1.0, 'gbx': True, 'position': 68, 'target_weight': 0.08}, {'name': 'BATG', 'ticker': 'BATG.LSE', 'ccy': 'GBP', 'USD_exposure': 1.0, 'gbx': True, 'position': 173, 'target_weight': 0.12}, {'name': 'YCA', 'ticker': 'YCA.LSE', 'ccy': 'GBP', 'USD_exposure': 1.0, 'gbx': True, 'position': 689, 'target_weight': 0.5}, {'name': 'CASH_CHF', 'type': 'cash', 'ccy': 'CHF', 'amount': 11953, 'target_weight': 0.0}, {'name': 'CASH_JPY', 'ticker': 'JPYCHF.FOREX', 'type': 'cash', 'ccy': 'JPY', 'amount': 11416, 'target_weight': 0.0}, {'name': 'CASH_GBP', 'ticker': 'GBPCHF.FOREX', 'type': 'cash', 'ccy': 'GBP', 'amount': -2936, 'target_weight': 0.0}]
# data_params: {'start': Timestamp('2018-01-01 00:00:00'), 'datasource': 'stooq', 'max_age': 24, 'end': Timestamp('2026-05-11 00:00:00')}
# ------
# BOOK: IBKR_live
# -------
# max_age (hrs): 24
# -------
# Top 10 spikes for XMWX (|log return| > 0.07):
# Date
# 2026-04-01    0.310273
# 2026-01-14    0.298585
# 2026-01-21    0.292384
# 2026-01-16    0.290879
# 2025-12-22    0.290724
# 2025-12-23    0.289988
# 2026-04-02    0.286894
# 2026-01-22    0.286494
# 2025-04-04    0.038660
# 2026-03-03    0.033985
# Name: Close, dtype: float64
# WARNING: 8 spikes exceed threshold 0.07
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 100, in build_returns_weights
#     logger.debug('r, r*100 ', r.std(), (r*100).std()  )
# Message: 'r, r*100 '
# Arguments: (0.04234833749847206, 4.234833749847207)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 117, in build_returns_weights
#     logger.debug('asset close local s', asset_close_local_s.iloc[-1])
# Message: 'asset close local s'
# Arguments: (np.float64(32.515),)
# DEBUG:geoquant.risk_matrix:Converting XMWX from GBP to CHF
# DEBUG:geoquant.risk_matrix:CHF close last for XMWX: 34.426882
# DEBUG:geoquant.risk_matrix:--------holdings-loop-EMIM--------
# DEBUG:geoquant.risk_matrix:>>>>>>>>>>>>>> Processing EMIM >>>>>>>>
# DEBUG:geoquant.data_io:+++fetch_csv : EMIM.LSE, config/data_params:
# DEBUG:geoquant.data_io:EMIM.UK - using cached data (no refresh)
# INFO:geoquant.data_io:changes: []
# INFO:geoquant.data_io:  EMIM.UK - no flat-bar spikes detected in cached data
# DEBUG:geoquant.risk_matrix:              Open    High      Low   Close  Volume
# Date
# 2026-05-08  4040.0  4072.0  4020.44  4065.0  327475
# INFO:geoquant.series_utils:Spike check: EMIM (top 10, threshold 0.07)
# INFO:geoquant.series_utils:Spike check FAILED for EMIM: 4 spikes exceed threshold 0.07
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 92, in build_returns_weights
#     logger.debug('px local earliest date', sx.index[0].date())
# Message: 'px local earliest date'
# Arguments: (datetime.date(2018, 1, 2),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 93, in build_returns_weights
#     logger.debug('px local latest', sx.iloc[-1])
# Message: 'px local latest'
# Arguments: (np.float64(4065.0),)
# DEBUG:geoquant.risk_matrix:<bound method NDFrame.tail of Date
# 2018-01-02    2253.00
# 2018-01-03    2293.75
# 2018-01-04    2301.25
# 2018-01-05    2314.50
# 2018-01-08    2315.25
#                ...
# 2026-05-01    3866.00
# 2026-05-05    3955.00
# 2026-05-06    4045.00
# 2026-05-07    4041.00
# 2026-05-08    4065.00
# Name: Close, Length: 2109, dtype: float64>
# DEBUG:geoquant.risk_matrix:Max data gap (days) for EMIM: 5.0
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 100, in build_returns_weights
#     logger.debug('r, r*100 ', r.std(), (r*100).std()  )
# Message: 'r, r*100 '
# Arguments: (0.01143909161900448, 1.1439091619004473)
# Top 10 spikes for EMIM (|log return| > 0.07):
# Date
# 2020-03-12    0.117278
# 2020-03-27    0.075008
# 2020-03-09    0.074275
# 2020-03-13    0.073561
# 2022-03-16    0.055628
# 2020-03-16    0.055284
# 2026-03-03    0.050445
# 2020-03-24    0.049638
# 2026-04-08    0.049158
# 2022-06-16    0.045604
# Name: Close, dtype: float64
# WARNING: 4 spikes exceed threshold 0.07
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 117, in build_returns_weights
#     logger.debug('asset close local s', asset_close_local_s.iloc[-1])
# Message: 'asset close local s'
# Arguments: (np.float64(4065.0),)
# DEBUG:geoquant.risk_matrix:Converting EMIM from GBP to CHF
# DEBUG:geoquant.risk_matrix:CHF close last for EMIM: 43.04022
# DEBUG:geoquant.risk_matrix:--------holdings-loop-GWX--------
# DEBUG:geoquant.risk_matrix:>>>>>>>>>>>>>> Processing GWX >>>>>>>>
# DEBUG:geoquant.data_io:+++fetch_csv : GWX.US, config/data_params:
# DEBUG:geoquant.data_io:GWX.US - using cached data (no refresh)
# INFO:geoquant.data_io:changes: []
# INFO:geoquant.data_io:  GWX.US - no flat-bar spikes detected in cached data
# DEBUG:geoquant.risk_matrix:             Open   High    Low  Close   Volume
# Date
# 2026-05-08  46.89  47.11  46.76  46.96  50099.0
# INFO:geoquant.series_utils:Spike check: GWX (top 10, threshold 0.07)
# INFO:geoquant.series_utils:Spike check FAILED for GWX: 4 spikes exceed threshold 0.07
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 92, in build_returns_weights
#     logger.debug('px local earliest date', sx.index[0].date())
# Message: 'px local earliest date'
# Arguments: (datetime.date(2018, 1, 2),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
# ...
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 133, in build_returns_weights
#     logger.debug('>chf equiv latest', asset_close_chf_s.iloc[-1])
# Message: '>chf equiv latest'
# Arguments: (np.float64(0.00495701),)
# DEBUG:geoquant.risk_matrix:--------holdings-loop-CASH_GBP--------
# DEBUG:geoquant.risk_matrix:>>>>>>>>>>>>>> Processing CASH_GBP >>>>>>>>
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 117, in build_returns_weights
#     logger.debug('asset close local s', asset_close_local_s.iloc[-1])
# Message: 'asset close local s'
# Arguments: (np.float64(1.0588),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mp/2szq6ct92zl4hbdd0y18rqyw0000gn/T/ipykernel_66947/3657198426.py", line 14, in <module>
#     rets_df, prices_df, w = risk_matrix.build_returns_weights(holdings, data_params=config.data_params, no_fx=False, usd_shift=False)
#   File "/Users/alexwebb/laptop_coding/risk_matrix/src/geoquant/risk_matrix.py", line 133, in build_returns_weights
#     logger.debug('>chf equiv latest', asset_close_chf_s.iloc[-1])
# Message: '>chf equiv latest'
# Arguments: (np.float64(1.0588),)
# DEBUG:geoquant.risk_matrix:===========df built===============
#
# INFO:geoquant.risk_matrix:After alignment only 415 rows remain (expected 3052 days 00:00:00). Data source may not have full history.
# DEBUG:geoquant.risk_matrix:CHF value 497 of XMWX: 17110.16
# DEBUG:geoquant.risk_matrix:CHF value 321 of EMIM: 13815.91
# DEBUG:geoquant.risk_matrix:CHF value 203 of GWX: 7406.29
# DEBUG:geoquant.risk_matrix:CHF value 39 of VUAG: 4317.62
# DEBUG:geoquant.risk_matrix:CHF value 68 of SGLN: 4831.39
# DEBUG:geoquant.risk_matrix:CHF value 173 of BATG: 5510.74
# DEBUG:geoquant.risk_matrix:CHF value 689 of YCA: 4264.00
# DEBUG:geoquant.risk_matrix:CHF value 0.0 of CASH_CHF: 11953.00
# DEBUG:geoquant.risk_matrix:CHF value 0.0 of CASH_JPY: 56.59
# DEBUG:geoquant.risk_matrix:CHF value 0.0 of CASH_GBP: -3108.64
# INFO:geoquant.risk_matrix:LOOKBACK DAYS/REGIME: 2018-01-01 00:00:00 to 2026-05-11 00:00:00  (3052 days)
# DEBUG:geoquant.risk_matrix:Total portfolio value (CHF): 66157.06
# DEBUG:geoquant.risk_matrix:XMWX: value CHF17110.16,  last 32.66 *fx* 497
# DEBUG:geoquant.risk_matrix:EMIM: value CHF13815.91,  last 40.41 *fx* 321
# DEBUG:geoquant.risk_matrix:GWX: value CHF7406.29,  last 46.42 *fx* 203
# DEBUG:geoquant.risk_matrix:VUAG: value CHF4317.62,  last 104.44 *fx* 39
# DEBUG:geoquant.risk_matrix:SGLN: value CHF4831.39,  last 67.58 *fx* 68
# DEBUG:geoquant.risk_matrix:BATG: value CHF5510.74,  last 30.29 *fx* 173
# DEBUG:geoquant.risk_matrix:YCA: value CHF4264.00,  last 5.99 *fx* 689
# DEBUG:geoquant.risk_matrix:CASH_CHF: value CHF11953.00,  last 1.00 *fx* 0.0
# DEBUG:geoquant.risk_matrix:CASH_JPY: value CHF56.59,  last 0.00 *fx* 0.0
# DEBUG:geoquant.risk_matrix:CASH_GBP: value CHF-3108.64,  last 1.06 *fx* 0.0
# INFO:geoquant.risk_matrix:++++++ portfolio_risk()
# asset close chf EMIM 40.65
# ------------
# Portfolio σ (an_adjnualized, CHF): 23.28%
#  CORE EQUITY BAND = 15 - 30%, DIVERSIFIERS = 5 - 12%, TACTICALS <= 10%,
# equity core max 30%, diversifiers max 12%, tacticals max 10%, total max 15%
# RISK ["SUMMARY"]:
#           Weight  Vol_1Y_CHF    MRC  PRC_%
# XMWX       0.259       0.667  0.612   68.0
# EMIM       0.209       0.175  0.099    8.8
# VUAG       0.065       0.480  0.315    8.8
# BATG       0.083       0.274  0.139    5.0
# YCA        0.064       0.365  0.154    4.3
# GWX        0.112       0.165  0.071    3.4
# SGLN       0.073       0.214  0.066    2.1
# CASH_JPY   0.001       0.079  0.005    0.0
# CASH_CHF   0.181       0.000  0.000    0.0
# CASH_GBP  -0.047       0.067  0.019   -0.4
# CORRELATION:
#           XMWX  EMIM   GWX  VUAG  SGLN  BATG   YCA  CASH_CHF  CASH_JPY  \
# XMWX      1.00  0.26  0.18  0.56  0.16  0.21  0.18       NaN      0.06
# EMIM      0.26  1.00  0.63  0.28  0.24  0.75  0.44       NaN      0.02
# GWX       0.18  0.63  1.00  0.20  0.33  0.52  0.32       NaN      0.20
# VUAG      0.56  0.28  0.20  1.00  0.09  0.25  0.23       NaN     -0.01
# SGLN      0.16  0.24  0.33  0.09  1.00  0.24  0.26       NaN      0.09
# BATG      0.21  0.75  0.52  0.25  0.24  1.00  0.46       NaN     -0.01
# YCA       0.18  0.44  0.32  0.23  0.26  0.46  1.00       NaN     -0.01
# CASH_CHF   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN
# CASH_JPY  0.06  0.02  0.20 -0.01  0.09 -0.01 -0.01       NaN      1.00
# CASH_GBP  0.15  0.40  0.57  0.16  0.17  0.29  0.19       NaN      0.31
#
#           CASH_GBP
# XMWX          0.15
# EMIM          0.40
# GWX           0.57
# VUAG          0.16
# SGLN          0.17
# BATG          0.29
# YCA           0.19
# CASH_CHF       NaN
# CASH_JPY      0.31
# CASH_GBP      1.00
# COVARIANCE:
# DEBUG:matplotlib.colorbar:locator: <matplotlib.ticker.AutoLocator object at 0x1577f4380>
#               XMWX      EMIM       GWX      VUAG      SGLN      BATG  \
# XMWX      0.444821  0.029922  0.019297  0.177677  0.022908  0.039156
# EMIM      0.029922  0.030617  0.018285  0.023467  0.009005  0.036055
# GWX       0.019297  0.018285  0.027114  0.015803  0.011456  0.023335
# VUAG      0.177677  0.023467  0.015803  0.230389  0.009143  0.032510
# SGLN      0.022908  0.009005  0.011456  0.009143  0.045718  0.013827
# BATG      0.039156  0.036055  0.023335  0.032510  0.013827  0.074820
# YCA       0.044200  0.028175  0.018938  0.041024  0.020470  0.045880
# CASH_CHF  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# CASH_JPY  0.003189  0.000327  0.002564 -0.000340  0.001549 -0.000218
# CASH_GBP  0.006878  0.004700  0.006384  0.005052  0.002454  0.005343
#
#                YCA  CASH_CHF  CASH_JPY  CASH_GBP
# XMWX      0.044200       0.0  0.003189  0.006878
# EMIM      0.028175       0.0  0.000327  0.004700
# GWX       0.018938       0.0  0.002564  0.006384
# VUAG      0.041024       0.0 -0.000340  0.005052
# SGLN      0.020470       0.0  0.001549  0.002454
# BATG      0.045880       0.0 -0.000218  0.005343
# YCA       0.132932       0.0 -0.000163  0.004710
# CASH_CHF  0.000000       0.0  0.000000  0.000000
# CASH_JPY -0.000163       0.0  0.006262  0.001678
# CASH_GBP  0.004710       0.0  0.001678  0.004550

# %%
def eod_search(quey: str, token: str):
    import requests, pandas as pd
    url = f"https://eodhd.com/api/search/{quey}?api_token={token}&fmt=json"
    r = requests.get(url, timeout=30); r.raise_for_status()
    hits = r.json()
    # Return a small table to pick from
    return pd.DataFrame([{
        "code": h.get("Code"),
        "exchange": h.get("Exchange"),
        "name": h.get("Name"),
        "currency": h.get("Currency"),
        "type": h.get("Type"),
        "startdate": h.get("StartDate"),
        # earliet date

    } for h in hits])

# Usage:
df = eod_search("litg", config.EOD_API)
# pick the line with the longest available history (often XETRA/LSE/SIX)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 19
#       7     return pd.DataFrame([{
#       8         "code": h.get("Code"),
#       9         "exchange": h.get("Exchange"),
#    (...)     15
#      16     } for h in hits])
#      18 # Usage:
# ---> 19 df = eod_search("litg", config.EOD_API)
#      20 # pick the line with the longest available history (often XETRA/LSE/SIX)
#      21 print(df)
#
# AttributeError: module 'geoquant.configs.config' has no attribute 'EOD_API'

# %% [markdown]
# ## GET THE EARLIEST DATE ##

# %%
START = '2020-01-02'
ticker = 'XMWX.LSE'


# Fetch EODHD daily FX and build a Series
fx_df = f1.fetch_csv_robust(ticker, data_params=config.data_params)
print(fx_df.head(1))
# Out:
# XMWX.LSE - downloading fresh data
# XMWX.LSE - cleaned 2 flat-bar spike(s) on download
# data start date b4 saving: 2024-08-27
#                Open     High      Low    Close  Adjusted_close  Volume
# Date
# 2024-08-27  33.1258  33.1258  33.1258  33.1258         33.1258       0

# %% [markdown]
# ## Equity correlation drift check
# We’ll:
# - compute a 60-day rolling average pairwise correlation across the equity ETFs in your `rets_df`.
# - show the 1-year view you’re using now (limited by `XMWX`).
# - also compute a 3-year view excluding `XMWX` (if data exist), to see whether the increase is structural or just recent.

# %%
# 1) Current 1-year view (already in rets_df)
# Pick equity ETFs present in rets_df
all_cols = list(rets_df.columns)
EQUITY_LIKE = [c for c in ["EMIM","GWX","BATG","XMWX","SGLN", 'YCA'] if c in all_cols]

if len(EQUITY_LIKE) >= 2:
    rets_eq_1y = rets_df[EQUITY_LIKE]
    # 60D rolling average of pairwise correlation (off-diagonal mean)
    def offdiag_mean(corr_m):
        if corr_m.shape[0] < 2:
            return np.nan
        n = corr_m.shape[0]
        return (corr_m.values.sum() - n) / (n*(n-1))

    roll_avg_corr_1y = (
        rets_eq_1y.rolling(60).corr().groupby(level=0).apply(lambda c: offdiag_mean(c))
    )

    print("1Y rolling(60) avg pairwise equity corr (tail):")
    print(roll_avg_corr_1y.dropna().tail(10))
else:
    print("Not enough equity-like tickers to compute 1Y pairwise correlation.")

# 2) Longer 3Y view excluding XMWX (if data available): re-fetch or extend window is out of scope here,
# but we can approximate by checking if older data exist in prices_df; if not, we demonstrate exclusion-only.
try:
    # If you want to explicitly exclude XMWX to avoid its shorter history limiting the window
    EQUITY_NO_XMWX = [c for c in EQUITY_LIKE if c != "XMWX"]
    if len(EQUITY_NO_XMWX) >= 2:
        # Use available rets_df (1Y). For a true 3Y view, rerun 
        rets_eq_ex = rets_df[EQUITY_NO_XMWX]
        roll_avg_corr_ex = (
            rets_eq_ex.rolling(60).corr().groupby(level=0).apply(lambda c: offdiag_mean(c))
        )
        print("Ex-XMWX rolling(60) avg pairwise equity corr (tail):")
        print(roll_avg_corr_ex.dropna().tail(756))
    else:
        print("Not enough non-XMWX equity-like tickers to compute ex-XMWX correlation.")
except Exception as e:
    print("Correlation analysis note:", e)
# Out:
# 1Y rolling(60) avg pairwise equity corr (tail):
# Date
# 2026-04-23    0.486743
# 2026-04-24    0.485983
# 2026-04-27    0.499019
# 2026-04-28    0.498753
# 2026-04-29    0.497419
# 2026-04-30    0.504665
# 2026-05-01    0.508668
# 2026-05-05    0.504667
# 2026-05-06    0.505549
# 2026-05-07    0.502728
# dtype: float64
# Ex-XMWX rolling(60) avg pairwise equity corr (tail):
# Date
# 2024-11-26    0.398901
# 2024-11-27    0.395797
# 2024-11-29    0.397309
# 2024-12-02    0.369931
# 2024-12-03    0.362244
#                 ...
# 2026-04-30    0.607414
# 2026-05-01    0.610228
# 2026-05-05    0.603967
# 2026-05-06    0.603452
# 2026-05-07    0.599602
# Length: 354, dtype: float64
