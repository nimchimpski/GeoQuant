# %%
# Test single ticker download from stooq (FX: GBPCHF)
import logging
from geoquant.data_io import fetch_csv
from geoquant.configs import config
from geoquant.plotting import plot_spike_inspection

logging.getLogger().setLevel(logging.DEBUG)

test_ticker = 'SHEL.LSE'
test_params = config.data_params.copy()
# test_params['max_age'] = 0  # force download

df_test = fetch_csv(test_ticker, data_params=test_params)
print('Downloaded shape:', df_test.shape)
print(df_test.head(1))
print(df_test.tail(1))
plot_spike_inspection(series=df_test, name=test_ticker)
# Out:
# DEBUG:geoquant.data_io:+++fetch_csv : SHEL.LSE, config/data_params:
# INFO:geoquant.data_io:path not exists
# INFO:geoquant.data_io:SHEL.LSE - cache missing, downloading new data
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 13
#      10 test_params = config.data_params.copy()
#      11 # test_params['max_age'] = 0  # force download
# ---> 13 df_test = fetch_csv(test_ticker, data_params=test_params)
#      14 print('Downloaded shape:', df_test.shape)
#      15 print(df_test.head(1))
#
# File ~/laptop_coding/risk_matrix/src/geoquant/data_io.py:557, in fetch_csv(ticker, data_params, force_refresh)
#     555 data_params_full['start'] = start
#     556 data_params_full['end'] = end
# --> 557 df_raw = _download_csv_frame(build_url(datasource, ticker, data_params_full), ticker)
#     558 cleaned, audit = clean_price_spikes(df_raw)
#     559 _log_spike_audit(ticker, audit, source="download")
#
# File ~/laptop_coding/risk_matrix/src/geoquant/data_io.py:338, in build_url(datasource, ticker, data_params)
#     336     url = f'https://eodhd.com/api/eod/{ticker}?api_token={data_params["api_token"]}&from={start}&to={end}'
#     337 else:
# --> 338     raise ValueError(f"Unsupported datasource: {datasource}")
#     339 return url
#
# ValueError: Unsupported datasource: EOD

# %%
def eod_search(quey: str, token: str):
    import requests, pandas as pd
    url = f"https://eodhd.com/api/search/{quey}?api_token={token}&fmt=json"
    r = requests.get(url, timeout=30); r.raise_for_status()
    hits = r.json()
    # Return a small table to pick from
    return pd.DataFrame([{
        "code": h.get("Code"),
        "exchange": h.get("Exchange"),
        "name": h.get("Name"),
        "currency": h.get("Currency"),
        "type": h.get("Type"),
        "startdate": h.get("StartDate"),
        # earliet date

    } for h in hits])

# Usage:
df = eod_search("litg", config.EOD_API)
# pick the line with the longest available history (often XETRA/LSE/SIX)
print(df)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): eodhd.com:443
# DEBUG:urllib3.connectionpool:https://eodhd.com:443 "GET /api/search/litg?api_token=68b5e3ff8bb5d2.47603652&fmt=json HTTP/1.1" 401 None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 19
#       7     return pd.DataFrame([{
#       8         "code": h.get("Code"),
#       9         "exchange": h.get("Exchange"),
#    (...)     15
#      16     } for h in hits])
#      18 # Usage:
# ---> 19 df = eod_search("litg", config.EOD_API)
#      20 # pick the line with the longest available history (often XETRA/LSE/SIX)
#      21 print(df)
#
# Cell In[2], line 4, in eod_search(quey, token)
#       2 import requests, pandas as pd
#       3 url = f"https://eodhd.com/api/search/{quey}?api_token={token}&fmt=json"
# ----> 4 r = requests.get(url, timeout=30); r.raise_for_status()
#       5 hits = r.json()
#       6 # Return a small table to pick from
#
# File /opt/miniconda3/envs/riskmatrix/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://eodhd.com/api/search/litg?api_token=68b5e3ff8bb5d2.47603652&fmt=json
