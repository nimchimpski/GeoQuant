# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import importlib
import book
import functions1 
import config 

importlib.reload(book)
importlib.reload(functions1)
importlib.reload(config)

print(config.PROJECT_ROOT)
# Out:
# /Users/alexwebb/laptop_coding/risk_matrix

# %%
IBKR_live = book.IBKR_live
fetch_csv_robust = functions1.fetch_csv_robust
params = config.params
sort_cols = functions1.sort_cols

total = 0
for h in IBKR_live:
    exp = h.get("GBP_exposure")
    if exp is None:
        continue
    print(h.get("name"),'exposure:' ,h.get("GBP_exposure"))
    # get gbpchf last price
    ticker   = h.get("ticker")
    px_df = fetch_csv_robust(f'{ticker}', params=params,)
    px = sort_cols(px_df).iloc[-1]
    print('last:' ,px)
    position = h.get("position")
    mkt_val = position * px
    print('mkt val: £',mkt_val)
    fullfxrisk = position * px * exp
    print('full fxrisk: £',fullfxrisk)
    print('')
    total += fullfxrisk



    # Normalize, de-dup, and pick close-like series
    asset_close_local_s = sort_cols(px_df)
    #  hedge needed = position * last * GBP_exposure
    #  print (hedge needed)
    # total += hedge needed
print ('total: £',total)
# Out:
# ERNS exposure: 1.0
# last: 101.9
# mkt val: £ 9069.1
# full fxrisk: £ 9069.1
#
# HEAL exposure: 0.03
# last: 8.3775
# mkt val: £ 1507.9499999999998
# full fxrisk: £ 45.238499999999995
#
# WSML exposure: 0.04
# last: 8.802
# mkt val: £ 4251.366
# full fxrisk: £ 170.05464
#
# VEU exposure: 0.13
# last: 71.95
# mkt val: £ 4892.6
# full fxrisk: £ 636.0380000000001
#
# total: £ 9920.43114

# %%
# Out:
# {'computershare': [{'name': 'Unilever', 'ticker': 'ULVR.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 25000}, {'name': 'Shell', 'ticker': 'SHEL.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 13000}, {'name': 'NatWest', 'ticker': 'NWG.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 5000}, {'name': 'Barclays', 'ticker': 'BARC.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 5000}, {'name': 'Tesco', 'ticker': 'TSCO.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 5000}, {'name': 'SWDA', 'ticker': 'SWDA.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 12000}, {'name': 'EMIM', 'ticker': 'EMIM.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 8000}, {'name': 'IBM', 'ticker': 'IBM', 'ccy': 'USD', 'gbx': False, 'value_chf': 4000}, {'name': 'ERNS', 'ticker': 'ERNS.LON', 'ccy': 'GBP', 'gbx': True, 'value_chf': 5000}]}
# ...
